# %% [markdown]
# # Gerar tabela de conversão

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.dpi']= 150

veja = pd.read_csv('veja.csv')
folha = pd.read_csv('folha.csv')
estadao = pd.read_csv('estadao.csv')
uol = pd.read_csv('uol.csv')

keys = ['esporte', 'brasil', 'entretenimento', 'mundo', 'economia', 'politica', 'saude', 'ciencia', 'tecnologia', 'blog', 'placar', 'educacao', 'tveja', 'revista-veja', 'blogs', 'especiais', 'ideias', 'gastronomia']

# %%
def getColumnsWithThemes(f):
    return list(filter(lambda column: 'Tema' in column, f.columns))

def getColumnsValues(f):
    allThemes = set()
    for column in getColumnsWithThemes(f):
        for theme in f[column]:
            allThemes.add(theme)
    return allThemes


getColumnsValues(uol)
# Out:
# {'ageless#2019#02',
#  'agfight#ronda-rousey-rompe-o-silencio-apos-derrota-e-pede-tempo-para-refletir#',
#  'agoraequesaoelas#2017#05',
#  'airway#marinha-desativa-porta-avioes-sao-paulo#',
#  'altoastral#2018#04',
#  'amauryjr#2017#08',
#  'amauryjr#2018#11',
#  'amauryjr#2018#12',
#  'amauryjr#2019#03',
#  'andrerocha#2018#01',
#  'aovivo#2017#05',
#  'aovivo#2018#04',
#  'aovivo#2018#09',
#  'aovivo#2018#10',
#  'aovivo#cotidiano#2019',
#  'arte#mundo#2017',
#  'atarde#esportes#noticias',
#  'aventurasnahistoria#noticias#almanaque',
#  'aventurasnahistoria#noticias#galeria',
#  'aventurasnahistoria#noticias#historia-hoje',
#  'aventurasnahistoria#noticias#personagem',
#  'aventurasnahistoria#noticias#reportagem',
#  'blog#blogdofefito#2018',
#  'blogdamorango#2017#12',
#  'blogdamorango#2018#02',
#  'blogdamorango#2018#07',
#  'blogdamorango#2018#08',
#  'blogdamorango#2018#11',
#  'blogdamorango#2018#12',
#  'blogdamorango#2019#02',
#  'blogdoarcanjo#2017#05',
#  'blogdoarcanjo#2017#06',
#  'blogdobarcinski#2017#06',
#  'blogdojuca#2017#02',
#  'blogdojuca#2018#01',
#  'blogdojuca#2018#07',
#  'blogdojuca#2018#08',
#  'blogdojuliogomes#2018#06',
#  'blogdomenon#2017#05',
#  'blogdomenon#2017#08',
#  'blogdomenon#2017#10',
#  'blogdomenon#2017#12',
#  'blogdomenon#2018#01',
#  'blogdomenon#2018#05',
#  'blogdoohata#2017#05',
#  'blogdoohata#2018#01',
#  'blogdoohata#2018#07',
#  'blogdoperrone#2017#08',
#  'blogdoperrone#2017#11',
#  'blogdoperrone#2018#07',
#  'blogdorafaelreis#2018#06',
#  'blogdorafaelreis#2018#12',
#  'blogdosakamoto#2017#02',
#  'blogdosakamoto#2017#03',
#  'blogdosakamoto#2018#04',
#  'blogdosakamoto#2018#07',
#  'blogdosakamoto#2018#11',
#  'blogs#jamildo#2018',
#  'blogs#social1#2017',
#  'brasilianismo#2019#01',
#  'caras#atualidades#lexa-quebra-o-silencio-apos-prisao-do-marido-mc-guime-e-faz-duro-apelo-para-seguidor.phtml',
#  'caras#bem-estar#apos-perder-38-kg-luciano-camargo-aparece-sem-camisa-primeira-vez',
#  'caras#carnaval#sem-calcinha-juliana-paes-rouba-a-cena-durante-desfile-no-rio.phtml',
#  'caras#carnaval#thaila-ayala-rouba-cena-com-fantasia-sexy-de-policial-em-festa-no-rio',
#  'caras#musica#anitta-e-chamada-de-gostosa-durante-show-no-rio-grande-do-sul-e-da-resposta-sincerona',
#  'caras#musica#gravida-e-desempregada-seguidora-de-preta-gil-pede-mil-reais-para-a-cantora-e-recebe-resposta-inesperada.phtml',
#  'caras#musica#kelly-key-e-mico-freitas-se-reunem-em-restaurante-para-discutir-sobre-frequencia-amorosa.phtml',
#  'caras#musica#simaria-tem-nova-crise-e-simone-anuncia-pausa-na-carreira.phtml',
#  'caras#tv#aos-46-flavio-silvino-aparece-grisalho-em-foto-rara-ao-lado-do-irmao.phtml',
#  'caras#tv#apos-baby-do-brasil-casagrande-troca-carinhos-com-nova-namorada',
#  'caras#tv#carlinhos-maia-ganha-carro-de-luxo-do-marido-de-simone-e-desabafa-me-ama-muito.phtml',
#  'caras#tv#cleo-pires-vai-sem-sutia-a-evento-e-causa-alvoroco.phtml',
#  'caras#tv#conheca-namorada-bilionaria-de-enzo-celulari-que-e-sucesso-nas-redes-sociais',
#  'caras#tv#criticada-por-comportamento-domingao-do-faustao-narjara-turetta-desabafa.phtml',
#  'caras#tv#fatima-bernardes-rebate-polemica-com-martinho-da-vila-no-encontro-fas-se-revoltam.phtml',
#  'caras#tv#ganhadora-do-big-brother-brasil-cida-emilly-araujo-e-vitima-de-golpe-e-perde-todo-o-dinheiro-do-reality.phtml',
#  'caras#tv#globo-reve-decisao-e-coloca-4-crianca-na-final-do-the-voice-kids.phtml',
#  'caras#tv#gretchen-publica-foto-rara-aos-18-anos-e-choca-fas-o-clone-da-thammy',
#  'caras#tv#namorada-de-marcelo-rezende-emociona-fas-ao-compartilhar-momento-final-com-o-apresentador',
#  'caras#tv#patricia-e-mauro-naves-chance-ao-amor-estamos-namorando',
#  'caras#tv#tadeu-schmidt-desabafa-sobre-ser-filho-temporao-sempre-me-ressenti-muito-disso',
#  'caras#tv#tatuagem-de-bruna-marquezine-vira-piada-na-web-apos-fas-descobrirem-erro-ortografico-neymar-paris.phtml',
#  'caras#tv#veja-como-estao-os-participantes-do-big-brother-brasil-1-bbb-globo-apos-15-anos',
#  'caras#tv#xuxa-rompe-o-silencio-historico-sobre-marlene-mattos-e-revela-me-sentia-usada-abusada.phtml',
#  'caras#viagem#luciana-gimenez-faz-video-de-biquini-e-quase-mostra-demais.phtml',
#  'carlosmelo#2018#10',
#  'carnaval#2017#listas',
#  'carnaval#2017#noticias',
#  'carnaval#2018#colunas',
#  'carnaval#2018#enquetes',
#  'carnaval#2018#noticias',
#  'carplace#novo-vw-polo-2018-e-maior-e-melhor-do-que-todos-os-antecessores#',
#  'carros#colunas#alta-roda',
#  'carros#colunas#cacador-de-carros',
#  'carros#listas#dez-motos-que-devem-abalar-o-mercado-de-duas-rodas-no-brasil-em-2018.htm',
#  'carros#listas#e-tudo-mentira-conheca-cinco-mitos-sobre-o-oleo-do-seu-carro.htm',
#  'carros#listas#economize-combustivel-10-dicas-simples-de-seguir-para-poupar-com-seu-carro.htm',
#  'carros#listas#veja-dez-mitos-e-verdades-sobre-o-uso-da-gasolina-aditivada.htm',
#  'carros#listas#veja-quais-sao-os-10-carros-automaticos-mais-baratos-do-brasil.htm',
#  'carros#noticias#bbc',
#  'carros#noticias#redacao',
#  'carros#noticias#reuters',
#  'carsale#2017#05',
#  'cenapop#2017#02',
#  'cenapop#2017#03',
#  'cenapop#2017#06',
#  'cenapop#2018#06',
#  'cenapop#2018#07',
#  'cenapop#2018#09',
#  'cenapop#2018#12',
#  'chicobarney#2018#07',
#  'chicobarney#2018#09',
#  'chicobarney#2018#11',
#  'chicobarney#2018#12',
#  'chicobarney#2019#03',
#  'cinema#album#2017',
#  'cinema#listas#cocaina-e-palavroes-5-historias-do-bozo-que-parecem-ficcao-mas-nao-sao.htm',
#  'cinema#noticias#afp',
#  'cinema#noticias#redacao',
#  'comidasebebidas#noticias#agencia-estado',
#  'comidasebebidas#noticias#redacao',
#  'congressoemfoco#corrupcao#presidente-da-cni-robson-andrade-e-preso-em-operacao-que-mira-convenios-do-ministerio-do-turismo',
#  'congressoemfoco#justica#promotores-e-procuradores-levam-desembargador-que-mandou-soltar-lula-ao-cnj',
#  'congressoemfoco#noticias#apenas-tres-senadores-compareceram-a-todas-as-sessoes-em-2017-veja-quem-mais-faltou',
#  'congressoemfoco#noticias#ex-governador-do-df-roriz-enfrenta-diabetes-amputacao-de-perna-e-nao-reconhece-amigos',
#  'congressoemfoco#noticias#garotinho-e-preso-pela-segunda-vez-em-menos-de-um-ano',
#  'congressoemfoco#noticias#gilmar-mendes-e-hostilizado-em-voo-se-cala-e-sorri-veja-o-video',
#  'congressoemfoco#noticias#lula-dilma-e-ciro-vao-reinaugurar-obra-de-transposicao-do-sao-francisco',
#  'congressoemfoco#noticias#marco-aurelio-confessa-inimizade-com-gilmar-escolheria-uma-arma-de-fogo',
#  'congressoemfoco#noticias#maria-do-rosario-vai-a-pf-para-punir-responsaveis-por-exibicao-de-fotos-intimas-da-filha',
#  'congressoemfoco#noticias#ninguem-aguenta-mais-tanto-roubo-disse-geddel-em-ato-contra-corrupcao',
#  'congressoemfoco#noticias#novas-regras-para-rotativo-do-cartao-de-credito-valem-a-partir-de-amanha',
#  'congressoemfoco#noticias#receita-consolida-regras-sobre-declaracao-do-imposto-de-renda',
#  'congressoemfoco#noticias#revogacao-de-prisao-de-neto-de-ex-senador-causa-revolta-na-paraiba',
#  'congressoemfoco#noticias#solto-e-no-exercicio-do-mandato-aecio-pode-acabar-com-a-lava-jato-diz-deltan-dallagnol',
#  'congressoemfoco#noticias#trf-derruba-decisao-de-moro-e-dispensa-lula-de-comparecer-a-mais-de-80-depoimentos',
#  'contigo#noticias#exclusivas',
#  'contigo#noticias#ultimas',
#  'copadomundo#2018#noticias',
#  'cornetafc#2017#08',
#  'cornetafc#2018#02',
#  'cozinhabruta#?p=249#undefined',
#  'drauziovarella#checagens#remedio-para-gastrite-ulcera-e-refluxo-dobra-o-risco-de-cancer',
#  'economia#blogs-e-colunas#coluna',
#  'economia#empregos-e-carreiras#noticias',
#  'economia#financas-pessoais#noticias',
#  'economia#imposto-de-renda#duvidas',
#  'economia#imposto-de-renda#noticias',
#  'economia#listas#do-pequeno-acougue-ao-luxo-11-curiosidades-sobre-a-jbs-e-os-irmaos-batista.htm',
#  'economia#noticias#bbc',
#  'economia#noticias#efe',
#  'economia#noticias#estadao-conteudo',
#  'economia#noticias#redacao',
#  'economia#noticias#reuters',
#  'educacao#noticias#bbc',
#  'eleicoes#2018#noticias',
#  'entretenimento#album#2017',
#  'entretenimento#cinema#noticia',
#  'entretenimento#colunas#chico-barney',
#  'entretenimento#famosos#galeria',
#  'entretenimento#famosos#noticia',
#  'entretenimento#famosos#noticias',
#  'entretenimento#listas#7-brinquedos-que-enlouqueciam-os-pais-nos-anos-1980.htm',
#  'entretenimento#listas#the-big-bang-theory-perde-o-posto-de-serie-mais-vista-do-ano-veja-lista.htm',
#  'entretenimento#miss#brasil',
#  'entretenimento#noticias#redacao',
#  'espn#noticia#661140_atacante-lembra-festa-de-dois-dias-de-r10-que-fez-ate-seguranca-pedir-arrego-tenho-familia',
#  'espn#noticia#664472_1min17-para-colocar-fogo-no-jogo-em-numeros-como-foi-a-estreia-de-jesus-pelo-city',
#  'espn#noticia#664700_para-fraudar-regulamento-destaque-de-finalista-da-copinha-usa-documentos-de-preso-acusado-de-trafico-de-drogas',
#  'espn#noticia#708302_aos-16-anos-promessa-do-santos-gera-ciumes-e-polemica-por-renovacao-com-salario-maior-que-o-de-neymar',
#  'espn#noticia#718789_apos-quase-abandonar-a-carreira-e-vencer-o-desemprego-campeao-mundial-pelo-corinthians-quer-renascer-na-serie-b',
#  'espn#noticia#748434_porrada-com-mansell-prost-ladrao-de-mulheres-e-rivalidade-com-senna-piquet-abre-o-jogo-30-anos-apos-o-tri',
#  'espnw#thaisa-conta-seu-drama-ver-minha-perna-definhando-e-assustador#',
#  'esporte#basquete#ultimas-noticias',
#  'esporte#boxe#ultimas-noticias',
#  'esporte#f1#listas',
#  'esporte#f1#ultimas-noticias',
#  'esporte#fotos#10000012751',
#  'esporte#futebol#album',
#  'esporte#futebol#campeonatos',
#  'esporte#futebol#copa-do-mundo',
#  'esporte#futebol#de-primeira',
#  'esporte#futebol#ultimas-noticias',
#  'esporte#ginastica#ultimas-noticias',
#  'esporte#lutas#ultimas-noticias',
#  'esporte#mma#ultimas-noticias',
#  'esporte#radicais#ultimas-noticias',
#  'esporte#reportagens-especiais#entrevista---aloisio-chulapa',
#  'esporte#reportagens-especiais#entrevista---thiago-duarte-peixoto-o-arbitro-que-errou-expulsao-em-palmeiras-x-corinthians',
#  'esporte#reportagens-especiais#entrevista-elia-junior',
#  'esporte#reportagens-especiais#minha-historia-ingrid-oliveira',
#  'esporte#reportagens-especiais#orlando-lele-qual-a-verdade-sobre-a-morte-do-ex-jogador-da-selecao',
#  'esporte#reportagens-especiais#pesquisao---futebol-brasileiro---2018',
#  'esporte#reportagens-especiais#ronaldo-10-anos-da-chegada-do-fenomeno-ao-corinthians',
#  'esporte#surfe#ultimas-noticias',
#  'esporte#ultimas-noticias#2017',
#  'esporte#ultimas-noticias#2018',
#  'esporte#ultimas-noticias#2019',
#  'esporte#ultimas-noticias#ag-fight',
#  'esporte#ultimas-noticias#bbc',
#  'esporte#ultimas-noticias#efe',
#  'esporte#velocidade#ultimas-noticias',
#  'esporte#volei#ultimas-noticias',
#  'estilo#album#2017',
#  'estilo#beleza#noticias',
#  'estilo#casa-e-decoracao#album',
#  'estilo#casa-e-decoracao#noticias',
#  'estilo#casa-e-decoracao#projetos',
#  'estilo#casamento#noticias',
#  'estilo#comportamento#album',
#  'estilo#comportamento#listas',
#  'estilo#comportamento#noticias',
#  'estilo#gravidez-e-filhos#noticias',
#  'estilo#horoscopo#mensais',
#  'estilo#moda#noticias',
#  'estilo#noticias#redacao',
#  'estilo#vida-saudavel#listas',
#  'estilo#vida-saudavel#noticias',
#  'f5#astrologia#2018',
#  'f5#bichos#2017',
#  'f5#celebridades#2017',
#  'f5#celebridades#2018',
#  'f5#colunistas#cristina-padiglione',
#  'f5#colunistas#fernando-oliveira',
#  'f5#colunistas#tonygoes',
#  'f5#musica#2017',
#  'f5#musica#2018',
#  'f5#televisao#2018',
#  'f5#voceviu#2017',
#  'f5#voceviu#2018',
#  'forbes#forbeslife#2018',
#  'forbes#lifestyle#2018',
#  'forbes#listas#2018',
#  'futebol#futebol#brasileirao',
#  'gizmodo#injecao-semen-braco-dor-costas#',
#  'gizmodo#tarantula-come-cobra#',
#  'glamurama#ao-que-tudo-indica-marcelo-de-carvalho-recem-separado-de-luciana-gimenez-ja-fez-a-fila-andar#',
#  'glamurama#aos-17-ronald-ataca-de-dj-frequenta-baladas-de-gente-grande-e-conta-porque-fugiu-do-futebol#',
#  'glamurama#bruna-marquezine-fim-de-namoro-com-neymar-e-possivel-novo-affair-al-mare-vem-saber#',
#  'glamurama#caio-blat-sobre-seu-papel-em-deus-salve-o-rei-acho-que-foi-erro-de-escalacao#',
#  'glamurama#filha-de-narcisa-tamborindeguy-catharina-johannpeter-se-casou-com-tres-dias-de-festa#',
#  'glamurama#galeria#casamento-de-roberta-gradel-e-priscila-raab-agitou-o-copacabana-palace',
#  'glamurama#galeria#glamurama-mostra-e-conta-tudo-o-que-rolou-na-8a-edicao-do-gala-da-amfar',
#  'glamurama#herdeiro-da-maior-rede-de-hoteis-do-mundo-processa-o-proprio-pai-depois-de-ser-deserdado#',
#  'glamurama#marcelo-de-carvalho-e-simone-abdelnur-em-clima-de-lua-de-mel-na-italia-vem-ver#',
#  'glamurama#o-bilionario-mais-discreto-do-brasil-tambem-foi-o-que-mais-ganhou-dinheiro-em-2018-quem-e-ele#',
#  'glamurama#personal-trainer-revela-corpao-de-bruna-marquezine-e-o-mais-cobicado-do-momento#',
#  'glamurama#revista-j-p-acompanhou-de-perto-o-julgamento-do-crime-do-papai-noel#',
#  'glamurama#solidao-antidepressivos-e-livros-de-autoajuda-a-vida-de-adriana-ancelmo-na-prisao-domiciliar#',
#  'goo#NpEUtU#undefined',
#  'grandepremio#f1#noticias',
#  'guiadoscuriosos#blog#2017',
#  'harpersbazaar#moda#kate-middleton-recicla-look-para-casamento-real',
#  'historiasdomar#2018#05',
#  'historiasdomar#2018#07',
#  'historiasdomar#2018#08',
#  'hugogloss#cool#vinoinstagram',
#  'hugogloss#famosos#gisele-bundchen-comenta-por-que-terminou-com-leonardo-dicaprio-e-relembra-receio-com-o-bumbum-em-desfile',
#  'infomoto#2018#04',
#  'jamilchade#2019#02',
#  'jamilchade#2019#03',
#  'jconline#canal#cidades',
#  'jconline#canal#cultura',
#  'jconline#canal#esportes',
#  'jconline#canal#mundo',
#  'jconline#canal#opiniao',
#  'jconline#canal#politica',
#  'jogos#listas#estes-super-herois-sao-gays-e-voce-nao-sabia.htm',
#  'jogos#listas#tem-um-desses-itens-em-casa-voce-pode-estar-rico-sem-saber.htm',
#  'jogos#ultimas-noticias#2017',
#  'josiasdesouza#2017#01',
#  'josiasdesouza#2017#02',
#  'josiasdesouza#2017#03',
#  'josiasdesouza#2017#04',
#  'josiasdesouza#2017#05',
#  'josiasdesouza#2017#06',
#  'josiasdesouza#2017#10',
#  'josiasdesouza#2017#12',
#  'josiasdesouza#2018#01',
#  'josiasdesouza#2018#02',
#  'josiasdesouza#2018#03',
#  'josiasdesouza#2018#04',
#  'josiasdesouza#2018#05',
#  'josiasdesouza#2018#06',
#  'josiasdesouza#2018#07',
#  'josiasdesouza#2018#08',
#  'josiasdesouza#2018#09',
#  'josiasdesouza#2018#10',
#  'josiasdesouza#2018#11',
#  'josiasdesouza#2018#12',
#  'josiasdesouza#2019#02',
#  'josiasdesouza#2019#03',
#  'jovempan#entretenimento#tv-e-cinema',
#  'jovempan#noticias#brasil',
#  'jovempan#noticias#politica',
#  'jovempan#programas#camisa10',
#  'jovempan#programas#jornal-da-manha',
#  'liabock#2017#08',
#  'liabock#2018#01',
#  'liabock#2018#02',
#  'liabock#2019#01',
#  'lucianabugni#2018#07',
#  'lucianabugni#2018#12',
#  'luizasahd#2018#02',
#  'maquinadoesporte#artigo#apos-sao-paulo-poty-fecha-com-corinthians_36157.html',
#  'marcelrizzo#2017#11',
#  'marcelrizzo#2018#12',
#  'matheuspichonelli#2018#03',
#  'mauriciostycer#2017#01',
#  'mauriciostycer#2017#02',
#  'mauriciostycer#2017#04',
#  'mauriciostycer#2017#05',
#  'mauriciostycer#2017#07',
#  'mauriciostycer#2017#08',
#  'mauriciostycer#2017#10',
#  'mauriciostycer#2017#11',
#  'mauriciostycer#2017#12',
#  'mauriciostycer#2018#01',
#  'mauriciostycer#2018#02',
#  'mauriciostycer#2018#03',
#  'mauriciostycer#2018#04',
#  'mauriciostycer#2018#05',
#  'mauriciostycer#2018#07',
#  'mauriciostycer#2018#08',
#  'mauriciostycer#2018#10',
#  'mauriciostycer#2018#12',
#  'mauriciostycer#2019#01',
#  'maxima#noticias#famosos',
#  'mayumisato#2017#10',
#  'mensageirosideral#2017#05',
#  'mensageirosideral#2017#07',
#  'mensageirosideral#2017#10',
#  'mensageirosideral#2018#11',
#  'musica#album#2017',
#  'musica#listas#com-o-fim-do-programa-o-que-anda-fazendo-o-sexteto-do-jo.htm',
#  'musica#listas#nao-e-so-anitta-veja-quem-mais-foi-traida-pelo-look-e-pagou-peitinho.htm',
#  'musica#noticias#redacao',
#  'nagradedomma#2017#02',
#  nan,
#  'natelinha#bbb#2018',
#  'natelinha#celebridades#2017',
#  'natelinha#celebridades#2018',
#  'natelinha#colunas#2017',
#  'natelinha#colunas#coluna-do-sanduba',
#  'natelinha#famosos#2018',
#  'natelinha#noticias#2017',
#  'natelinha#noticias#2018',
#  'natelinha#novelas#2018',
#  'natelinha#televisao#2019',
#  'navitrine#2017#09',
#  'navitrine#2018#09',
#  'nilsonxavier#2017#09',
#  'nilsonxavier#2017#12',
#  'nilsonxavier#2018#02',
#  'ninalemos#2017#09',
#  'ninalemos#2017#11',
#  'ninalemos#2018#06',
#  'noticias#album#2017',
#  'noticias#album#2018',
#  'noticias#album#2019',
#  'noticias#ao-vivo#2018',
#  'noticias#brasil#noticia',
#  'noticias#carnaval#2019',
#  'noticias#cidades#noticia',
#  'noticias#cidades#noticias',
#  'noticias#ciencia#ultimas-noticias',
#  'noticias#comprova#ultimas-noticias',
#  'noticias#confere#ultimas-noticias',
#  'noticias#cotidiano#ultimas-noticias',
#  'noticias#internacional#ultimas-noticias',
#  'noticias#meio-ambiente#ultimas-noticias',
#  'noticias#mundo#noticia',
#  'noticias#politica#eleicoes',
#  'noticias#politica#ultimas-noticias',
#  'noticias#saude#ultimas-noticias',
#  'noticias#tabloide#ultimas-noticias',
#  'noticias#tecnologia#noticias',
#  'noticias#ultimas-noticias#afp',
#  'noticias#ultimas-noticias#agencia-brasil',
#  'noticias#ultimas-noticias#agencia-estado',
#  'noticias#ultimas-noticias#bbc',
#  'noticias#ultimas-noticias#deutschewelle',
#  'noticias#ultimas-noticias#efe',
#  'noticias#ultimas-noticias#reuters',
#  'noticiasdatv#noticia#bbb',
#  'noticiasdatv#noticia#celebridades',
#  'noticiasdatv#noticia#mercado',
#  'noticiasdatv#noticia#mulher',
#  'noticiasdatv#noticia#novelas',
#  'noticiasdatv#noticia#series',
#  'noticiasdatv#noticia#televisao',
#  'noticiasdatv#noticia#videos',
#  'observatoriodatelevisao#curiosidade-da-tv#2017',
#  'observatoriodatelevisao#famosos#2017',
#  'observatoriodatelevisao#noticia-da-tv#2017',
#  'observatoriodocinema#famosos#2016',
#  'observatoriodocinema#famosos#2017',
#  'observatoriodocinema#famosos#2018',
#  'observatoriodocinema#listas#2017',
#  'observatoriodocinema#listas#2018',
#  'observatoriodosfamosos#noticias#2018',
#  'olharolimpico#2017#08',
#  'olharolimpico#2018#08',
#  'omundoemmovimento#2017#08',
#  'omundoemmovimento#2017#10',
#  'operamundi#conteudo#geral',
#  'paginacinco#2017#06',
#  'paginacinco#2018#02',
#  'paginacinco#2018#08',
#  'paginacinco#2018#11',
#  'paginacinco#2018#12',
#  'painel#2017#03',
#  'painel#2017#04',
#  'painel#2017#05',
#  'painel#2017#06',
#  'painel#2017#07',
#  'painel#2017#08',
#  'painel#2017#10',
#  'painel#2017#11',
#  'painel#2018#03',
#  'painel#2018#04',
#  'painel#2018#07',
#  'painel#2018#08',
#  'painel#2018#09',
#  'painel#2018#10',
#  'painel#2018#11',
#  'painel#2018#12',
#  'painel#2019#01',
#  'painel#2019#03',
#  'painel#?p=19669#undefined',
#  'paisefilhos#crianca#goleiro-elissom-anuncia-a-morte-do-filho-de-6-anos-lucca',
#  'paranaportal#cidades#curitiba-rmc-litoral',
#  'paranaportal#geral#curitibana-vai-passar-ferias-no-rn-e-descobre-que-foto-sua-ilustra-carrinhos-de-crepes',
#  'paranaportal#operacao-lava-jato#cunha-se-nega-a-fazer-exame-e-sera-penalizado-na-cadeia',
#  'paranaportal#operacao-lava-jato#defesa-de-lula-afirma-que-vai-acionar-delegado-da-pf-judicialmente',
#  'paranaportal#operacao-lava-jato#mpf-desiste-de-pericia-em-contratos-de-aluguel-de-lula',
#  'paranaportal#padrao#4267-procuradores-protesto-moro',
#  'paranaportal#policial#ex-prefeito-que-desviou-cilindro-de-oxigenio-para-bombear-chope-vai-responder-por-homicidio',
#  'patadasygambetas#2018#01',
#  'patadasygambetas#2018#04',
#  'patadasygambetas#2018#05',
#  'paulosampaio#2017#05',
#  'paulosampaio#2017#06',
#  'paulosampaio#2017#07',
#  'paulosampaio#2017#08',
#  'paulosampaio#2017#10',
#  'paulosampaio#2017#11',
#  'paulosampaio#2018#01',
#  'paulosampaio#2018#05',
#  'paulosampaio#2018#06',
#  'paulosampaio#2018#08',
#  'paulosampaio#2018#09',
#  'paulosampaio#2018#10',
#  'paulosampaio#2019#01',
#  'paulosampaio#2019#02',
#  'piaui#bolsonaro-e-haddad-vao-ao-jn-bombam-no-twitter-e-crescem#',
#  'piaui#bolsonaro-esse-demonio-nao-sabia-fazer-essas-coisas#',
#  'piaui#bolsonaro-nao-queria-sair-da-santa-casa#?doing_wp_cron=1537058895.9687728881835937500000',
#  'piaui#c#como-o-pcc-superou-a-policia-para-assassinar-um-lider-da-propria-faccao',
#  'piaui#c#lupa',
#  'piaui#das-falas-de-mourao-13o-foi-maior-tiro-no-pe#undefined',
#  'piaui#deputados-do-psl-na-china-mandam-recado-para-bolsonaro-sobre-previdencia#undefined',
#  'piaui#divida-milionaria-tortura-psicologica-e-chacina-sem-tiros-intrigam-policia#',
#  'piaui#governo-temer-pede-deputados-do-pt-para-impedir-greve-dos-petroleiros#',
#  'piaui#lupa#2018',
#  'piaui#um-protesto-historico-menos-na-teve#',
#  'placar#2018#1turno',
#  'publico#lifestyle#artigo',
#  'publico#mundo#noticia',
#  'pvc#2018#01',
#  'pvc#2018#07',
#  'recreio#noticias#curiosidades',
#  'recreio#noticias#zoo',
#  'reginanavarro#2017#09',
#  'reginanavarro#2017#10',
#  'reginanavarro#2017#12',
#  'revistatrip#tpm#mara-gabrilli-sexo-deficiencia',
#  'revistatrip#tpm#milly-lacombe-faz-um-relato-de-sua-experiencia-no-curso-de-sexo-tantrico-de-carol-teixeira?utm_source=uol&utm_medium=home&utm_campaign=milly-lacombe-faz-um-relato-de-sua-experiencia-no-curso-de-sexo-tantrico-de-carol-teixeira',
#  'revistatrip#trip#e-proibido-nascer-em-fernando-de-noronha',
#  'revistatrip#trip#um-dos-maiores-youtubers-do-mundo-whinderson-revela-como-cria-como-vive-e-como-administra-a-fama?utm_source=uol&utm_medium=home&utm_campaign=um-dos-maiores-youtubers-do-mundo-whinderson-revela-como-cria-como-vive-e-como-administra-a-fama',
#  'robertosadovski#2017#01',
#  'rodrigomattos#2017#03',
#  'rodrigomattos#2017#11',
#  'rodrigomattos#2018#06',
#  'saidaderede#2017#06',
#  'saidaderede#2017#08',
#  'saidaderede#2018#02',
#  'saqueevoleio#2017#04',
#  'soumaiseu#noticias#acredito-no-amor',
#  'tab#aristocracia#',
#  'tab#crise-venezuela#',
#  'tab#edicao#bolsonaro',
#  'tab#vagina#',
#  'tecfront#2019#01',
#  'tecnologia#listas#caiu-no-gemidao-do-whatsapp-6-dicas-para-isso-nao-se-repetir.htm',
#  'tecnologia#listas#carregar-bateria-ate-100-estraga-o-celular-confira-essa-e-outras-dicas.htm',
#  'tecnologia#listas#made-in-brazil-conheca-7-grandes-invencoes-criadas-por-brasileiros.htm',
#  'tecnologia#listas#mais-tempo-e-menos-textao-por-que-as-pessoas-saem-do-facebook.htm',
#  'tecnologia#noticias#bbc',
#  'tecnologia#noticias#redacao',
#  'tecnologia#reportagens-especiais#a-saga-dos-pais-por-dados-da-familia-desaparecida-em-brumadinho',
#  'telepadi#bozo-perde-cotacao-saida-de-carla-vilhena-da-globo-sinaliza-forca-de-novas-vitrines#',
#  'telepadi#briga-fisica-precedeu-lista-de-300-demissoes-na-band-o-que-vem-ai#',
#  'telepadi#daniella-perez-25-anos-o-dia-em-que-o-noticiario-superou-novela#undefined',
#  'telepadi#jo-soares-finalmente-conversa-e-chora-com-bial#',
#  'temas#projeto-amazonia#',
#  'tnonline#noticias#cotidiano',
#  'todosabordo#2017#01',
#  'todosabordo#2017#05',
#  'todosabordo#2017#06',
#  'todosabordo#2017#10',
#  'todosabordo#2017#12',
#  'todosabordo#2018#02',
#  'todosabordo#2018#03',
#  'todosabordo#2018#05',
#  'todosabordo#2019#01',
#  'tribunadoceara#noticias#segurancapublica',
#  'tvefamosos#a-fazenda#a-fazenda-9',
#  'tvefamosos#album#2017',
#  'tvefamosos#album#2018',
#  'tvefamosos#bbb#',
#  'tvefamosos#bbb#bbb17',
#  'tvefamosos#bbb#bbb18',
#  'tvefamosos#bbb#bbb19',
#  'tvefamosos#blog#mauriciostycer',
#  'tvefamosos#colunas#flavio-ricco',
#  'tvefamosos#enquetes#2019',
#  'tvefamosos#listas#amor-de-bancada-os-jornalistas-que-ja-se-envolveram-nos-bastidores-da-tv.htm',
#  'tvefamosos#listas#apos-porchat-sasha-sai-do-casulo-engata-namoro-e-conhece-a-ira-da-web.htm',
#  'tvefamosos#listas#as-7-vezes-que-cleo-pires-bombou.htm',
#  'tvefamosos#listas#as-musas-dos-anos-90-que.htm',
#  'tvefamosos#listas#assim-como-carol-duarte-veja-10-famosas-que-assumiram-romance-com-mulheres.htm',
#  'tvefamosos#listas#ate-bonner-chorou-6-vezes-em-que-jornalistas-nao-seguraram-a-emocao-na-tv.htm',
#  'tvefamosos#listas#ator-mirim-ancora-e-humorista-dez-demissoes-inesperadas-do-sbt-em-2017.htm',
#  'tvefamosos#listas#beijo-bagunca-e-carlos-alberto-rambo-a-lua-de-mel-do-dono-da-praca.htm',
#  'tvefamosos#listas#birkheuer-marquezine-casadevall-e-mais-famosas-que-mostraram-os-mamilos.htm',
#  'tvefamosos#listas#bumbum-na-nuca-nude-treino-7-vezes-em-que-gracyanne-quebrou-a-internet.htm',
#  'tvefamosos#listas#de-nutricionista-a-funkeira-onde-andam-ex-panicats-que-deixaram-o-panico.htm',
#  'tvefamosos#listas#de-prazer-anal-a-palavrao-na-tv-5-vezes-que-sandy-largou-de-ser-certinha.htm',
#  'tvefamosos#listas#domingao-com-climao-7-saias-justas-que-estremeceram-ate-faustao-na-tv.htm',
#  'tvefamosos#listas#fofocando-na-uti-programa-afunda-ainda-mais-e-ja-respira-por-aparelhos.htm',
#  'tvefamosos#listas#gretchen-carrieri-5-artistas-que-estrelaram-porno-e-venceram-preconceito.htm',
#  'tvefamosos#listas#internet-e-governo-onde-estao-os-jornalistas-que-deixaram-a-globo-em-2018.htm',
#  'tvefamosos#listas#longe-dos-holofotes-eles-sao-filhos-de-famosos-mas-nao-ligam-para-a-fama.htm',
#  'tvefamosos#listas#masterchef-brasil-5-participantes-que-se-rebelaram-contra-o-reality.htm',
#  'tvefamosos#listas#nua-exausta-e-sem-perereca-gimenez-explica-5-fotos-do-instagram.htm',
#  'tvefamosos#listas#o-loco-meu-veja-10-bailarinas-do-domingao-que-ja-ofuscaram-faustao.htm',
#  'tvefamosos#listas#oito-situacoes-bebrasileiras-que-inspiraram-falcatruas-de-segundo-sol.htm',
#  'tvefamosos#listas#pagina-virada-15-profissionais-que-sairam-da-globo-no-ultimo-ano.htm',
#  'tvefamosos#listas#paradinha-topless-jantar-de-dicaprio-o-1-mes-de-marquezine-solteira.htm',
#  'tvefamosos#listas#por-onde-andam-6-atrizes-que-comecaram-a-carreira-como-mocas-brejeiras.htm',
#  'tvefamosos#listas#quatro-cenas-prometidas-que-voce-nao-viu-em-o-outro-lado-do-paraiso.htm',
#  'tvefamosos#listas#relembre-cinco-casais-famosos-que-transformaram-a-amizade-em-amor.htm',
#  'tvefamosos#listas#sem-vergonha-dez-vezes-em-que-famosos-contaram-detalhes-da-vida-sexual.htm',
#  'tvefamosos#listas#sergio-guize-ana-paula-arosio-paula-fernandes-famosos-que-moram-no-campo.htm',
#  'tvefamosos#listas#sete-vezes-que-o-outro-lado-do-paraiso-nao-fez-sentido-algum.htm',
#  'tvefamosos#listas#talento-luxo-e-fama-a-vida-de-ticiana-villas-boas-antes-do-escandalo.htm',
#  'tvefamosos#listas#toda-forma-de-amor-famosos-que-assumiram-relacionamentos-gays-e-nos-amamos.htm',
#  'tvefamosos#noticias#ooops',
#  'tvefamosos#noticias#redacao',
#  'tvuol#video#lula-se-irrita-com-insistencia-de-procurador-sobre-vaccari-nao-interessa-04020C9C3566C4916326',
#  'tvuol#video#por-que-a-gente-nao-deve-assoar-o-nariz-0402CC9B3564CC896326',
#  'tvuol#video#scarlett-johansson-deu-o-que-falar-em-hollywood-monogamia-nao-e-natural-04020E193562D0896326',
#  'universa#album#2018',
#  'universa#especiais#eu-sugar-baby',
#  'universa#especiais#michelle-bolsonaro',
#  'universa#especiais#o-novo-sexo-das-minas',
#  'universa#especiais#sem-filtro-betty-faria',
#  'universa#especiais#so-mulher-sabe',
#  'universa#noticias#bbc',
#  'universa#noticias#redacao',
#  'uol#bbkjcK#undefined',
#  'uol#blkgb3#undefined',
#  'uol#bxj64x#undefined',
#  'uol#bxkdd4#undefined',
#  'uolesporte#2017#01',
#  'uolesporte#2017#03',
#  'uolesporte#2017#04',
#  'uolesporte#2017#06',
#  'uolesporte#2017#08',
#  'uolesporte#2017#10',
#  'uolesporte#2017#11',
#  'uolesporte#2017#12',
#  'uolesporte#2018#01',
#  'uolesporte#2018#03',
#  'uolesporte#2018#04',
#  'uolesporte#2018#05',
#  'uolesporte#2018#08',
#  'uolesporte#2018#10',
#  'uolesporte#2018#12',
#  'uolesporte#2019#01',
#  'uolesporte#2019#02',
#  'uolesporte#2019#03',
#  'uolesportevetv#2017#02',
#  'uolesportevetv#2017#04',
#  'uolesportevetv#2017#05',
#  'uolesportevetv#2017#06',
#  'uolesportevetv#2017#07',
#  'uolesportevetv#2017#08',
#  'uolesportevetv#2017#09',
#  'uolesportevetv#2017#11',
#  'uolesportevetv#2018#01',
#  'uolesportevetv#2018#05',
#  'uolesportevetv#2018#06',
#  'uolesportevetv#2018#07',
#  'uolesportevetv#2018#08',
#  'uolesportevetv#2018#09',
#  'uolesportevetv#2018#11',
#  'uolesportevetv#2018#12',
#  'uoltecnologia#2017#01',
#  'veronicalaino#2018#09',
#  'viagem#listas#destinos-para-praticar-suingue-sexo-a-tres-e-outras-aventuras-com-seu-par.htm',
#  'viagem#listas#praias-de-nudismo-tem-regras-internas-conheca-e-evite-gafes.htm',
#  'viagem#noticias#2017',
#  'viagem#noticias#2018',
#  'viagem#noticias#2019',
#  'virgula#casa-e-comida#zeze-di-camargo-compra-apartamento-de-luxo-veja-mansoes-de-astros ',
#  'virgula#comportamento#jovem-mata-100-militantes-do-isis-e-tem-recompensa-de-us-1-milhao-por-sua-cabeca',
#  'virgula#inacreditavel#motorista-encontra-animal-exotico-nos-pneus-e-ele-acaba-ganhando-amor-e-carinho',
#  'virgula#inacreditavel#ostentacao-familia-indiana-vive-sozinha-em-arranha-ceu-de-27-andares',
#  'virgula#inacreditavel#principe-da-arabia-saudita-compra-lugares-para-seus-80-falcoes-em-aviao-vem-ver-a-foto',
#  'virgula#modaebeleza#essas-modelos-australianas-querem-acabar-com-comparacao-entre-as-mulheres',
#  'vivabem#album#2019',
#  'vivabem#colunas#adriana-miranda',
#  'vivabem#listas#11-dicas-para-ter-um-sexo-melhor-de-acordo-com-a-ciencia.htm',
#  'vivabem#listas#4-habitos-alimentares-que-voce-evitar-na-terceira-idade.htm',
#  'vivabem#listas#5-coisas-comuns-no-dia-a-dia-que-podem-causar-mau-halito.htm',
#  'vivabem#listas#6-coisas-que-acontecem-com-nosso-corpo-logo-depois-que-transamos.htm',
#  'vivabem#listas#9-alimentos-que-voce-come-mesmo-a-ciencia-tendo-comprovado-que-fazem-mal.htm',
#  'vivabem#listas#9-atitudes-que-voce-deve-ter-agora-para-prevenir-a-demencia-na-velhice.htm',
#  'vivabem#noticias#bbc',
#  'vivabem#noticias#redacao',
#  'vivabem#reportagens-especiais#corpo-novo-em-12-semanas',
#  'www#copadomundo#especiais',
#  'www#economia#especiais',
#  'www#educacao#especiais',
#  'www#eleicoes#especiais',
#  'www#entretenimento#especiais',
#  'www#especiais#bastidoresdocarnaval',
#  'www#esporte#especiais',
#  'www#estilo#especiais',
#  'www#jornalismo#cidades',
#  'www#jornalismo#da-para-acreditar',
#  'www#jornalismo#desafios',
#  'www#jornalismo#mundo',
#  'www#memes#album',
#  'www#noticias#especiais',
#  'www#superpop#videos',
#  'www#tvfama#blog',
#  'www#tvfama#videos',
#  'www1#ambiente#2019',
#  'www1#ciencia#2017',
#  'www1#colunas#bernardomellofranco',
#  'www1#colunas#bruno-boghossian',
#  'www1#colunas#celso-rocha-de-barros',
#  'www1#colunas#claudiacollucci',
#  'www1#colunas#demetriomagnoli',
#  'www1#colunas#eliogaspari',
#  'www1#colunas#janiodefreitas',
#  'www1#colunas#laura-carvalho',
#  'www1#colunas#leandrocolon',
#  'www1#colunas#mauriciostycer',
#  'www1#colunas#mercadoaberto',
#  'www1#colunas#miriangoldenberg',
#  'www1#colunas#monicabergamo',
#  'www1#colunas#nelsondesa',
#  'www1#colunas#pedrodiniz',
#  'www1#colunas#redesocial',
#  'www1#colunas#reinaldoazevedo',
#  'www1#cotidiano#2017',
#  'www1#cotidiano#2018',
#  'www1#cotidiano#2019',
#  'www1#educacao#2017',
#  'www1#educacao#2018',
#  'www1#educacao#2019',
#  'www1#equilibrioesaude#2017',
#  'www1#esporte#2017',
#  'www1#esporte#2018',
#  'www1#ilustrada#2017',
#  'www1#ilustrada#2018',
#  'www1#mercado#2017',
#  'www1#mercado#2018',
#  'www1#mercado#2019',
#  'www1#mundo#2017',
#  'www1#mundo#2018',
#  'www1#mundo#2019',
#  'www1#opiniao#2017',
#  'www1#opiniao#2018',
#  'www1#poder#2017',
#  'www1#poder#2018',
#  'www1#poder#2019',
#  'www1#seminariosfolha#2018',
#  'www1#sobretudo#negocios',
#  'www1#sobretudo#rodas',
#  'www1#turismo#2018',
#  'www1#tv#poder',
#  'www2#guiadolitoral#materias',
#  'www3#blog#reinaldo',
#  'zip#bctDNX#undefined',
#  'zip#bdtGTv#undefined',
#  'zip#bltFxS#undefined',
#  'zip#bmtHz2#undefined',
#  'zip#bntLmg#undefined',
#  'zip#brtFTZ#undefined'}
